# %%
import boto3
import pandas as pd

# %%
s3 = boto3.resource(
    service_name="s3",
    region_name="us-east-1",
    aws_access_key_id="AKIAXMGV5DSYBX4MMMOE",
    aws_secret_access_key="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")

# %%
for obj in s3.Bucket('bigtastytestbucket').objects.all():
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='bigtastytestbucket', key='features_2|20|2023_0000_part_00')
# s3.ObjectSummary(bucket_name='bigtastytestbucket', key='features_2|20|2023_0001_part_00')

# %%
object1 = s3.Bucket('bigtastytestbucket').Object('features_2|20|2023_0000_part_00').get()
object2 = s3.Bucket('bigtastytestbucket').Object('features_2|20|2023_0001_part_00').get()

output1 = pd.read_csv(object1['Body'])
output2 = pd.read_csv(object2['Body'])

final_output = pd.concat([output1, output2])
f = open("features.parquet.gzip", "w")
f.truncate()
f.close()
final_output.to_parquet('features.parquet.gzip', compression='gzip', index=False)

# %%
pd.read_parquet('features.parquet.gzip')
# Out:
#                                    track_uri release_date  popularity_rating  \
# 0       spotify:track:0eGsygTp906u18L0Oimnem   2004-06-15                  0
# 1       spotify:track:0PWgAyoxsjwGRuFSO0fyya   2010-10-25                 61
# 2       spotify:track:0ZUo4YjG4saFnEJhdWp9Bt   2005-11-14                 75
# 3       spotify:track:1CQ2cMfrmFM1YdfmjENKVE   2014-06-27                 69
# 4       spotify:track:1dzQoRqT5ucxXVaAhTcT0J   2008-01-01                 77
# ...                                      ...          ...                ...
# 223655  spotify:track:3j4JOeXU20JrrYGHXCr1EY         1999                 43
# 223656  spotify:track:3qtsVB90KMoccHtSCbAHOE   1992-11-13                 55
# 223657  spotify:track:3YEz7DrxZbXnEfxIJ0tjE1   1999-09-10                 26
# 223658  spotify:track:45Yq4VXS09JbvraL1W5VbY   1997-05-14                 17
# 223659  spotify:track:4JOjEDadsxI1wZo60GX9pH   1993-06-29                 45
#
# ...
