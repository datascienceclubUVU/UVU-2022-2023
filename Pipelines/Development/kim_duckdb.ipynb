# %%
import duckdb

# %%
# Connect to DuckDB
con = duckdb.connect(database=':memory:', read_only=False)

# %%
# Read CSV files into DuckDB relations
artists_relation = duckdb.read_csv("C:/Users/ninan.PLSNO/Documents/UVU Data Science/Dataset/temp_artists.csv")
audio_features_relation = duckdb.read_csv("C:/Users/ninan.PLSNO/Documents/UVU Data Science/Dataset/temp_audio_features.csv")
playlist_tracks_relation = duckdb.read_csv("C:/Users/ninan.PLSNO/Documents/UVU Data Science/Dataset/temp_playlist_tracks.csv")

# %%
# Perform SQL operations on the relations
result = con.execute("SELECT * FROM artists_relation").fetchall()
result
# Out:
# [(0, 'spotify:track:0000vdREvCVMxbQTkS888c', 'Rill', None, None, None, None),
#  (0,
#   'spotify:track:00023kzM0NKtbCAzMiYXwy',
#   'Emino',
#   'Swagg Man',
#   None,
#   None,
#   None),
#  (0,
#   'spotify:track:0005HhCeIUqi6jLSKRYBZw',
#   'Amellia Grey',
#   None,
#   None,
#   None,
#   None),
#  (0,
#   'spotify:track:000brQJEvEDAHPZjWyv6wx',
#   'Kaua Correia',
#   None,
#   None,
#   None,
#   None),
#  (0, 'spotify:track:000CSYu4rvd8cQ7JilfxhZ', 'Kaïn', None, None, None, None),
#  (0,
#   'spotify:track:000DsoWJKHdaUmhgcnpr8j',
#   'Trazan & Banarne',
#   None,
#   None,
#   None,
#   None),
#  (0,
#   'spotify:track:000FG580Dt08g1VJY3EAFU',
#   'Eban Thomas',
#   'Nas',
#   'The Last Poets',
#   None,
#   None),
#  (0,
#   'spotify:track:000H5JPWBNl28k4fD6svku',
#   'Los Bukis',
#   None,
#   None,
#   None,
#   None),
#  (0,
#   'spotify:track:000HoCMkO5w5BuqgU6TXUD',
#   'dollsaway',
#   None,
#   None,
#   None,
#   None),
#  (0,
# ...
